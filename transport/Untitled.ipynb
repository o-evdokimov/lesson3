# %%
with open('data-398-2019-05-28.json','r', encoding = 'cp1251') as transport:
        data = json.loads(transport.read())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9746bda1bebd> in <module>
#       1 with open('data-398-2019-05-28.json','r', encoding = 'cp1251') as transport:
# ----> 2         data = json.loads(transport.read())
#
# NameError: name 'json' is not defined

# %%
import json

# %%
with open('data-398-2019-05-28.json','r', encoding = 'cp1251') as transport:
        data = json.loads(transport.read())

# %%
streets = [ item['Street'] for item in data ]

# %%
print(streets[1])
# Out:
# набережная Тараса Шевченко

# %%
dict = {}

# %%
for street in streets:
# Out:
#   File "<ipython-input-9-0867554b1b9f>", line 1
#     for street in streets:
#                           ^
# SyntaxError: unexpected EOF while parsing

# %%
for street in streets:
        a=1

# %%
print(data['Street'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-32fe1d115347> in <module>
# ----> 1 print(data['Street'])
#
# TypeError: list indices must be integers or slices, not str

# %%
print(data)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
NotebookApp.iopub_data_rate_limit=3000000.0 (bytes/sec)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-bf883e4f2f98> in <module>
# ----> 1 NotebookApp.iopub_data_rate_limit=3000000.0 (bytes/sec)
#
# NameError: name 'sec' is not defined

# %%
NotebookApp.iopub_data_rate_limit=3000000.0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-07452c1d7db8> in <module>
# ----> 1 NotebookApp.iopub_data_rate_limit=3000000.0
#
# NameError: name 'NotebookApp' is not defined

# %%
for street in streets:
    print(street)
# Out:
# 3-й Дербеневский переулок
# набережная Тараса Шевченко
# набережная Тараса Шевченко
# 3-я Черепковская улица
# улица Сущёвский Вал
# Дубнинская улица
# Дубнинская улица
# Дубнинская улица
# Дубнинская улица
# улица 800-летия Москвы
# Дмитровское шоссе
# Дмитровское шоссе
# Дмитровское шоссе
# Дмитровское шоссе
# Дмитровское шоссе
# Дмитровское шоссе
# Дмитровское шоссе
# Дмитровское шоссе
# Локомотивный проезд
# Большая Академическая улица
# Большая Академическая улица
# улица Зои и Александра Космодемьянских
# улица Зои и Александра Космодемьянских
# улица Зои и Александра Космодемьянских
# улица Зои и Александра Космодемьянских
# улица Зои и Александра Космодемьянских
# улица Зои и Александра Космодемьянских
# Большая Академическая улица
# Дмитровское шоссе
# Дмитровское шоссе
# Дмитровское шоссе
# Дмитровское шоссе
# Дмитровское шоссе
# Дмитровское шоссе
# Дубнинская улица
# Дубнинская улица
# Дубнинская улица
# Дубнинская улица
# Дубнинская улица
# Дубнинская улица
# ...

# %%
for street in streets:
    if street in dict:
        dict[street] += 1
    else:
        dic[street] = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-151d36dce067> in <module>
#       3         dict[street] += 1
#       4     else:
# ----> 5         dic[street] = 1
#
# NameError: name 'dic' is not defined

# %%
for street in streets:
    if street in dict:
        dict[street] += 1
    else:
        dict[street] = 1

# %%
max_stops_street = max(dict.values())

# %%
print(max_stops_street)
# Out:
# 468
